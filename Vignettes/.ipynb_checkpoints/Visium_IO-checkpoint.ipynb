# %% [markdown]
# NOTES:
#
# - Eventually, these should be merged into a pull request for Seurat
#
# Data could be arranged in so many ways and formats. It would nice to have one function that reads them all into a Seurat object. For now, assume that directory contains information for only one library.
#
#
# Rules for reading gene expression:
# - First, try to read h5 file.
# - If it doesn't exist, look for filtered mtx.
# - If it doesn't exist, look for mtx.
# - If doesn't exist, stop and ask for help.
#
# Rules for reading spatial:

# %%
library(Seurat)
library(glue)
# Out:
# Warning message:
# “package ‘Seurat’ was built under R version 4.1.2”
# Attaching SeuratObject
#
# Warning message:
# “package ‘glue’ was built under R version 4.1.2”

# %%
source('sagan/R/visium_seurat_io.R')

# %% [markdown]
# # Single library

# %% [markdown]
# ## Case 0: filtered h5

# %%
obj0 <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case0/')
head(obj0@meta.data)
SpatialPlot(obj0, alpha=c(0, 1))
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# “'giveCsparse' has been deprecated; setting 'repr = "T"' for you”
#                  orig.ident    nCount_Spatial nFeature_Spatial
# AAACAAGTATCTCCCA SeuratProject 20935          5230
# AAACAATCTACTAGCA SeuratProject 14789          3646
# AAACACCAATAACTGC SeuratProject 34646          6272
# AAACAGAGCGACTCCT SeuratProject 16833          4506
# AAACCGGGTAGGTACC SeuratProject 33684          5971
# AAACCGTTCGTCCAGG SeuratProject 32563          6097
# plot without title

# %% [markdown]
# ## Case 1: filtered mtx

# %%
obj1 <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case1/')
head(obj1@meta.data)
SpatialPlot(obj1, alpha=c(0, 1))
# Out:
#                  orig.ident    nCount_Spatial nFeature_Spatial
# AAACAAGTATCTCCCA SeuratProject 20935          5230
# AAACAATCTACTAGCA SeuratProject 14789          3646
# AAACACCAATAACTGC SeuratProject 34646          6272
# AAACAGAGCGACTCCT SeuratProject 16833          4506
# AAACCGGGTAGGTACC SeuratProject 33684          5971
# AAACCGTTCGTCCAGG SeuratProject 32563          6097
# plot without title

# %% [markdown]
# ### 1a: select image

# %%
obj_lowres <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case1/', img_tag = 'lowres')

# %%
obj_hires <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case1/', img_tag = 'hires')

# %%
obj_lowres <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case1/', img_tag = 'lowres')
dim(obj_lowres@images[[1]]@image)

obj_hires <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case1/', img_tag = 'hires')
dim(obj_hires@images[[1]]@image)
# Out:
# [1] 600 576   3
# [1] 2000 1921    3

# %% [markdown]
# ## Case 2: unnested files

# %%
obj2 <- Load10X_Spatial_v2('~/Projects/Mestag/data/Visium10x_v1/Case2/')
head(obj2@meta.data)
SpatialPlot(obj2, alpha=c(0, 1))
# Out:
#                  orig.ident    nCount_Spatial nFeature_Spatial
# AAACAAGTATCTCCCA SeuratProject 20935          5230
# AAACAATCTACTAGCA SeuratProject 14789          3646
# AAACACCAATAACTGC SeuratProject 34646          6272
# AAACAGAGCGACTCCT SeuratProject 16833          4506
# AAACCGGGTAGGTACC SeuratProject 33684          5971
# AAACCGTTCGTCCAGG SeuratProject 32563          6097
# plot without title

# %% [markdown]
# # Multiple libraries
#
# `TODO`
#
# - If names not specified, use the directory names

# %%
obj <- Read10X_generic(
    c('~/Projects//Mestag//data/Visium10x_v1/Case0/', '~/Projects//Mestag//data/Visium10x_v1/Case1/'), 
    'Spatial'
)
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# “'giveCsparse' has been deprecated; setting 'repr = "T"' for you”

# %%
head(obj)
# Out:
#                        orig.ident nCount_Spatial nFeature_Spatial
# Case0_AAACAAGTATCTCCCA Case0      20935          5230
# Case0_AAACAATCTACTAGCA Case0      14789          3646
# Case0_AAACACCAATAACTGC Case0      34646          6272
# Case0_AAACAGAGCGACTCCT Case0      16833          4506
# Case0_AAACCGGGTAGGTACC Case0      33684          5971
# Case0_AAACCGTTCGTCCAGG Case0      32563          6097
# Case0_AAACCTCATGAAGTTG Case0      63521          8545
# Case0_AAACGAAGAACATACC Case0      42166          7210
# Case0_AAACGAGACGGTTGAT Case0      36802          6943
# Case0_AAACGGTTGCGAACTG Case0      29986          6315

# %%
obj <- Read10X_generic(
    '~/Projects/Mestag//data/Visium10x_v1/Case0/', 
    'Spatial'
)
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# “'giveCsparse' has been deprecated; setting 'repr = "T"' for you”

# %%
head(obj)
# Out:
#                  orig.ident    nCount_Spatial nFeature_Spatial
# AAACAAGTATCTCCCA SeuratProject 20935          5230
# AAACAATCTACTAGCA SeuratProject 14789          3646
# AAACACCAATAACTGC SeuratProject 34646          6272
# AAACAGAGCGACTCCT SeuratProject 16833          4506
# AAACCGGGTAGGTACC SeuratProject 33684          5971
# AAACCGTTCGTCCAGG SeuratProject 32563          6097
# AAACCTCATGAAGTTG SeuratProject 63521          8545
# AAACGAAGAACATACC SeuratProject 42166          7210
# AAACGAGACGGTTGAT SeuratProject 36802          6943
# AAACGGTTGCGAACTG SeuratProject 29986          6315

# %% [markdown]
# `TODO`: only add prefix when reading multiple dirs.

# %%
obj <- Load10X_Spatial_v2(
    c(
        '~/Projects/Mestag/data/Visium10x_v1/Case0/'
#         ,
#         '~/Projects/Mestag/data/Visium10x_v1/Case1/',
#         '~/Projects/Mestag/data/Visium10x_v1/Case2/'
    )
#     , 
#     libnames = c('A', '321', 'C')
)
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# “'giveCsparse' has been deprecated; setting 'repr = "T"' for you”

# %%
## Check that we loaded multiple 
table(obj@meta.data$orig.ident)
names(obj@images)
# Out:
# SeuratProject
#          2702
# [1] "slice1"

# %%
obj <- Load10X_Spatial_v2(
    c(
        '~/Projects/Mestag/data/Visium10x_v1/Case0/',
        '~/Projects/Mestag/data/Visium10x_v1/Case1/',
        '~/Projects/Mestag/data/Visium10x_v1/Case2/'
    )
#     , 
#     libnames = c('A', '321', 'C')
)
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# “'giveCsparse' has been deprecated; setting 'repr = "T"' for you”
